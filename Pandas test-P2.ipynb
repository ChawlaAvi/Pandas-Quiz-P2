# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. The cumulative sum of a column in DataFrame

# %%
df = pd.DataFrame([["A", 1],
                   ["B", 2],
                   ["C", 3],
                   ["D", 4]], columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 2. Uniquely number individual group in Pandas GroupBy

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     A      3
# 3     D      4

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 3. Check if column has NaN values

# %%
df = pd.DataFrame([["A", np.NaN], ["A", 2], ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A    NaN
# 1     A    2.0
# 2     C    NaN
# 3     D    4.0

# %%
## start your code below
col_A_check = ... 
col_B_check = ... 
## end your code here

# %%
col_A_check, col_B_check

# %% [markdown]
# # 4. Append a list as a row to a DataFrame

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4

# %%
new_row = ["E", 5]

# %%
df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4
# 4     E      5

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 5. Get the first row of every unique value in a column

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     A      3
# 3     D      4

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 6. Identify the source of each row in Pandas Merge

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_A", "col_C"])

df1
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 7. Filter n-largest and n-smallest values from a DataFrame

# %%
df = pd.DataFrame([["A", 200], ["B", 400],
                   ["C", 100], ["D", 300]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A    200
# 1     B    400
# 2     C    100
# 3     D    300

# %%
k = 2

# %%
## start your code below
largest_k = ... 
## end your code here

# %%
largest_k

# %%
## start your code below
smallest_k = ... 
## end your code here

# %%
smallest_k

# %% [markdown]
# # 8. Map categorical data to unique integral values

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     A      3
# 3     D      4

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 9. Add prefix to every column name

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df

# %% [markdown]
# # 10. Convert categorical columns to one hot values

# %%
df = pd.DataFrame([["A"], ["B"],
                   ["C"], ["A"]], 
                  columns=["col_A"])

df
# Out:
#   col_A
# 0     A
# 1     B
# 2     C
# 3     A

# %%
## start your code below
new_df = ... 
## end your code here

# %%
new_df
